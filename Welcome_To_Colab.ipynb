# %%
student = {"name":"Thomas","age":17,"grade":4.0}
print(student)
# Out:
# {'name': 'Thomas', 'age': 17, 'grade': 4.0}

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car['brand'])
# Out:
# Toyota

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car["year"])
# Out:
# 2020

# %%
person = {"name": "Alice", "age": 25}
person["city"] = "Bogotá"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bogotá'}

# %%
person = {"name": "Alice", "age": 25, "city": "Bogota"}
person['age']=26
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'Bogota'}

# %%
person = {"name": "Alice", "age": 25, "city": "Bogota"}
del person['city']
print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits.values())
# Out:
# dict_values([3, 5, 2])

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
for key, value in fruits.items():
    print(key, value)
# Out:
# apple 3
# banana 5
# orange 2

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}
print("Luis" in grades)
# Out:
# True

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}
print("Pedro" in grades)
# Out:
# False

# %%
numbers = {"a": 10, "b": 20, "c": 30}
total = sum(numbers.values())
print(total)
# Out:
# 60

# %%
inventory = {"pens": 10, "notebooks": 5, "erasers": 8}
print(len(inventory))
# Out:
# 3

# %%
countries = {"Colombia": "Bogota", "France": "Paris", "Japan": "Tokyo"}
for country, capital in countries.items():
    print(country, "-", capital)
# Out:
# Colombia - Bogota
# France - Paris
# Japan - Tokyo

# %%
temperatures = {"Monday": 22, "Tuesday": 24, "Wednesday": 21, "Thursday": 23}
Mayor = max(temperatures.values())
print(Mayor)
# Out:
# 24
